# %% [markdown]
# # DonorsChoose.org Application Screening
# - https://www.kaggle.com/c/donorschoose-application-screening

# %%
import pandas as pd
DATA_DIR = "data-temp"

# %%
train_data =  pd.read_csv(DATA_DIR + "/train.csv", low_memory=False)

# %%
train_data['teacher_id2'] = pd.factorize(train_data['teacher_id'])[0]

# %%
train_data.groupby(['teacher_id2']).agg('count')
# Out:
#              id  teacher_id  teacher_prefix  school_state  \
# teacher_id2
# 0            10          10              10            10
# 1             1           1               1             1
# 2             4           4               4             4
# 3            16          16              16            16
# 4            10          10              10            10
# 5             3           3               3             3
# 6             2           2               2             2
# 7             2           2               2             2
# 8             3           3               3             3
# 9             4           4               4             4
# 10            4           4               4             4
# 11            1           1               1             1
# 12            1           1               1             1
# 13            2           2               2             2
# 14            1           1               1             1
# ...
